# %% [markdown]
# <a href="https://colab.research.google.com/github/MUHAMMADFAWWAZWIYOGA/DIF2130_A_25_2311532019/blob/main/Pratikum1/SimpleLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = { 'luas' : [ 6,8,10,14,18],
        'harga' : [ 7 , 9 ,13,17.5,18]}

df = pd.DataFrame (data)
print (df)
# Out:
#    luas  harga
# 0     6    7.0
# 1     8    9.0
# 2    10   13.0
# 3    14   17.5
# 4    18   18.0

# %%
import matplotlib.pyplot as plt

df.plot ( kind= 'scatter' , x='luas', y='harga')
plt.title ( 'perbandingan luas tanah dengan harga ')
plt.xlabel ( 'luas tanah ( m2)')
plt.ylabel ( 'harga ( juta )')
plt.xlim ( 0,25)
plt.ylim ( 0,25)
plt.grid ( True)
plt.show ()

# %%
import numpy as np

X = np.array(df['luas'])
y = np.array(df['harga'])

print(f'x : {X}')
print(f'y : {y}')
# Out:
# x : [ 6  8 10 14 18]
# y : [ 7.   9.  13.  17.5 18. ]

# %%
X = X.reshape(-1,1)

print(f'X shape : {X.shape}')
print(f'X : {X}')
# Out:
# X shape : (5, 1)
# X : [[ 6]
#  [ 8]
#  [10]
#  [14]
#  [18]]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
X_vis = np.array([0,25]).reshape(-1,1)
y_vis = model.predict(X_vis)

# %%
plt.scatter ( X,y)
plt.plot(X_vis, y_vis, color='red')

plt.title ( 'perbandingan luas tanah dengan harga ')
plt.xlabel ( 'luas tanah ( m2)')
plt.ylabel ( 'harga ( juta )')
plt.xlim ( 0,25)
plt.ylim ( 0,100)
plt.grid ( False)

# %%
print (f'intercept : {model.intercept_}')
print ( f'slope : {model.coef_}' )
# Out:
# intercept : 1.965517241379315
# slope : [0.9762931]

# %%
luas_tanah = np.array ([12,15,25]).reshape ( -1,1)
print (luas_tanah.shape)
luas_tanah
# Out:
# (3, 1)
# array([[12],
#        [15],
#        [25]])

# %%
harga_prediksi = model.predict(luas_tanah)
harga_prediksi
# Out:
# array([13.68103448, 16.60991379, 26.37284483])

# %%
X_train = np.array ( [6, 8 ,10 , 14,18 ]).reshape(-1,1)
y_train = np.array ( [7 ,9 ,13 , 17.5,18])

X_test =np.array ( [ 9,9,11,16,12]).reshape(-1,1)
y_test = np.array ([11,18,5,15,11])

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

y_pred = model.predict(X_test)
r_squared = r2_score(y_test, y_pred) # Assign the r2_score to r_squared
print ( f'R-squared : {r_squared}')
# Out:
# R-squared : -0.3107513899468637

# %%
# prompt: buatkan r squared dan jika r squared masih belum terbaik perbaiki hingga paing optimal , hasil masih kurang optimal berikan data training dan test sesuai anda hingga r squared menunjukan hasil terbaik

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# Generate more realistic data with some noise
np.random.seed(0)  # for reproducibility
n_samples = 50
X = np.linspace(6, 20, n_samples).reshape(-1, 1)
y = 2*X + np.random.normal(0, 2, size=(n_samples, 1)) # Linear relationship with added noise

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)


# Train the model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model using R-squared
r_squared = r2_score(y_test, y_pred)
print(f"R-squared: {r_squared}")

# Visualization
plt.scatter(X_train, y_train, label="Training Data")
plt.scatter(X_test, y_test, label="Testing Data", color='orange')
plt.plot(X_test, y_pred, color='red', label="Regression Line")
plt.xlabel("Luas Tanah (m2)")
plt.ylabel("Harga (juta)")
plt.title("Perbandingan Luas Tanah dengan Harga")
plt.legend()
plt.show()


# Example of how to improve R-squared (if needed -  this data should be already very good)
# You might consider polynomial regression if the relationship isn't truly linear
# from sklearn.preprocessing import PolynomialFeatures

# poly = PolynomialFeatures(degree=2) # Example: 2nd degree polynomial
# X_train_poly = poly.fit_transform(X_train)
# X_test_poly = poly.transform(X_test)

# model_poly = LinearRegression()
# model_poly.fit(X_train_poly, y_train)
# y_pred_poly = model_poly.predict(X_test_poly)
# r_squared_poly = r2_score(y_test, y_pred_poly)
# print(f"Polynomial R-squared: {r_squared_poly}")
# Out:
# R-squared: 0.9242405435395982

# %%
y_pred
# Out:
# array([10.75215517, 10.75215517, 12.70474138, 17.5862069 , 13.68103448])
